# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('../../static/csv/test_2.csv')
df.head()
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
# 3            4  What does the term "API" stand for in software...
# 4            5  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
# 3  ['Application Programming Interface','Advanced...               0
# 4  ['To test individual components or functions',...               0
#
#    field_id                                        skills_list
# 0         1  ['Version Control','Source Code Management','C...
# 1         1  ['Software Development Principles','DRY Princi...
# 2         1  ['Android Development','Java Programming','Mob...
# 3         1      ['API','Software Integration','Web Services']
# 4         1  ['Unit Testing','Software Testing','Code Quali...

# %%
# Convert the string representation of lists into actual lists
df['skills_list'] = df['skills_list'].apply(ast.literal_eval)
df.head()
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
# 3            4  What does the term "API" stand for in software...
# 4            5  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
# 3  ['Application Programming Interface','Advanced...               0
# 4  ['To test individual components or functions',...               0
#
#    field_id                                        skills_list
# 0         1  [Version Control, Source Code Management, Coll...
# 1         1  [Software Development Principles, DRY Principl...
# 2         1  [Android Development, Java Programming, Mobile...
# 3         1          [API, Software Integration, Web Services]
# 4         1     [Unit Testing, Software Testing, Code Quality]

# %%
# to lower case
df['skills_list'] = df['skills_list'].apply(lambda x: [y.lower() for y in x])
df.head()
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
# 3            4  What does the term "API" stand for in software...
# 4            5  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
# 3  ['Application Programming Interface','Advanced...               0
# 4  ['To test individual components or functions',...               0
#
#    field_id                                        skills_list
# 0         1  [version control, source code management, coll...
# 1         1  [software development principles, dry principl...
# 2         1  [android development, java programming, mobile...
# 3         1          [api, software integration, web services]
# 4         1     [unit testing, software testing, code quality]

# %%
# # save to csv
df.to_csv('../../static/csv/test_3.csv', index=False)

# %%
# replace '-' with ' '
df['skills_list'] = df['skills_list'].apply(lambda x: [y.replace('-', ' ') for y in x])

# %%
# remove strings 'skills' and 'skill'
df['skills_list'] = df['skills_list'].apply(lambda x: [y.replace('skills', '') for y in x])

# %%
# Create a list of skills by combining all the skills from the 'skills_list' column
all_skills = [skill for skills_list in df['skills_list'] for skill in skills_list]

# Now, 'all_skills' contains all the skills from the DataFrame
print(all_skills)
# Out:
# ['version control', 'source code management', 'collaborative development', 'software development principles', 'dry principle', 'code reusability', 'android development', 'java programming', 'mobile app development', 'api', 'software integration', 'web services', 'unit testing', 'software testing', 'code quality', 'data cleaning', 'data preprocessing', 'data analysis', 'data visualization', 'data analytics', 'data dashboards', 'tableau', 'data visualization', 'data analytics', 'data dashboards', 'tableau', 'sql', 'database querying', 'database management', 'statistics', 'median', 'data analysis', 'design principles', 'consistency in design', 'user interface design', 'color theory', 'complementary colors', 'color schemes', 'user testing', 'user experience testing', 'usability evaluation', 'design tools', 'wireframing', 'prototyping', 'ui/ux design software', 'product management', 'product manager', 'feature prioritization', 'product roadmap', 'product planning', 'product strategy', 'agile methodology', 'iterative development', 'customer feedback', 'scrum', 'product strategy', 'product documentation', 'product goals', 'mvp', 'product development', 'product launch', 'software testing', 'quality assurance', 'defect detection', 'regression testing', 'software testing', 'testing changes', 'load testing', 'software testing', 'performance testing', 'usability testing', 'user experience testing', 'user centered design', 'usability testing', 'user experience testing', 'user centered design', 'usability testing', 'user experience testing', 'user centered design', 'identity verification', 'authentication', 'access control', 'identity verification', 'authentication', 'access control', 'identity verification', 'authentication', 'access control', 'access control', 'security principles', 'authorization', 'access control', 'security principles', 'authorization', 'version control', 'git', 'svn', 'source code management', 'git', 'version control', 'collaborative development', 'code review', 'software development', 'collaborative development', 'continuous integration', 'ci/cd', 'software development practices', 'software architecture', 'software development', 'role of a software architect', 'devops', 'collaboration', 'continuous integration', 'software development practices', 'restful api', 'web services', 'api design', 'software development', 'agile software development', 'agile manifesto', 'scrum', 'software development principles', 'scrum framework', 'product owner', 'agile development', 'scrum roles', 'solid principles', 'object oriented design', 'software architecture', 'code maintainability', 'exploratory data analysis', 'data science', 'data analysis', 'statistical analysis', 'data preprocessing', 'machine learning', 'feature engineering', 'model performance', 'data dictionary', 'database management', 'metadata', 'data governance', 'big data', 'data processing', 'data analytics', 'nosql', 'data scientist', 'data analysis', 'predictive modeling', 'data driven decision making', 'data governance', 'data management', 'data quality', 'compliance', 'machine learning', 'data analysis', 'predictive modeling', 'pattern recognition', 'a/b testing', 'experimentation', 'data driven decision making', 'statistical analysis', 'data ethics', 'ethical data use', 'privacy', 'responsible ai', 'data security', 'data management', 'information security', 'cybersecurity', 'typography', 'graphic design', 'visual communication', 'brand identity', 'responsive design', 'user experience', 'web design', 'mobile responsiveness', 'information architecture', 'web design', 'user navigation', 'content organization', 'color psychology', 'design principles', 'emotional design', 'visual perception', 'motion design', 'user interfaces', 'interactive design', 'animation', 'user personas', 'user centered design', 'ux design', 'empathy in design', 'accessibility', 'inclusive design', 'usability', 'design ethics', 'prototyping', 'design process', 'user testing', 'iterative design',  ...

# %%
len(all_skills)
# Out:
# 231

# %%
# remove duplicates
all_skills = list(set(all_skills))

# %%
# sample skills from all_skills
sample = np.random.choice(all_skills, 10)
print(sample)
# Out:
# ['information architecture' 'data preprocessing' 'security policy'
#  'lean startup' 'user navigation' 'security measures' 'data quality'
#  'regression testing' 'color theory' 'role of a software architect']

# %%
# get unique skills
unique_skills = list(set(all_skills))
print(unique_skills)
# count the number of unique skills
print(len(unique_skills))
# Out:
# ['code review', 'security incident response plan', 'software development process', 'data analytics', 'code maintainability', 'biometric authentication', 'defect detection', 'iterative development', 'cybersecurity', 'usability', 'information security', 'interactive design', 'incident management', 'data scientist', 'data driven decision making', 'automation', 'color schemes', 'statistical analysis', 'endpoint security', 'information architecture', 'security analyst', 'threat mitigation', 'automated testing', 'defect identification', 'agile manifesto', 'product documentation', 'usability evaluation', 'adaptability in development', 'lean thinking', 'risk taking', 'median', 'authentication methods', 'version control', 'code reusability', 'api', 'typography', 'machine learning', 'dry principle', 'user experience', 'acceptance criteria', 'empathy in design', 'prototyping', 'organizational security', 'database management', 'performance evaluation', 'data governance', 'feature prioritization', 'environment compatibility', 'security measures', 'account security', 'visual perception', 'web services', 'exploratory testing', 'color psychology', 'load testing', 'software development principles', 'user centered design', 'visual communication', 'technical writer', 'data protection', 'api design', 'user acceptance testing', 'software development lifecycle', 'customer feedback', 'user experience testing', 'privacy', 'role of a software architect', 'continuous improvement', 'mobile responsiveness', 'ux design', 'knowledge transfer', 'fail fast', 'identity management', 'data processing', 'data quality', 'collaborative development', 'product strategy', 'java programming', 'software development practices', 'lean product development', 'data dashboards', 'scrum roles', 'compatibility testing', 'continuous integration', 'experimentation', 'ui/ux design', 'product management', 'user interfaces', 'color theory', 'learning culture', 'black box testing', 'design process', 'software development life cycle', 'data cleaning', 'information manipulation', 'identity verification', 'big data', 'pattern recognition', 'usability principles', 'tableau', 'lean startup', 'software architecture', 'data management', 'product success', 'design ethics', 'data visualization', 'device protection', 'data security', 'graphic design', 'statistics', 'data dictionary', 'source code management', 'cybersecurity threats', 'solid principles', 'exploratory data analysis', 'testing extremes', 'predictive modeling', 'testing methods', 'design principles', 'sql', 'accessibility', 'smoke testing', 'stress testing', 'user personas', 'agile development', 'interaction design', 'authorization', 'content organization', 'ethical data use', 'git', 'responsive design', 'build stability', 'responsible ai', 'documentation', 'testing phases', 'testing efficiency', 'product development', 'collaboration', 'authentication', 'compliance', 'product owner', 'scrum framework', 'test comprehensiveness', 'android development', 'user testing', 'testing techniques', 'usability testing', 'mvp', 'product planning', 'regression testing', 'brand identity', 'web design', 'emotional design', 'feature evaluation', 'network security', 'security principles', 'model performance', 'cross platform testing', 'user interface design', 'scrum', 'product goals', 'user experience optimization', 'access control', 'inclusive design', 'software integration', 'agile software development', 'phishing attacks', 'security incident handling', 'agile methodology', 'security controls', 'software development', 'fail cheap', 'object oriented design', 'devops', 'complementary colors', 'testing changes', 'vulnerability management', 'ci/cd', 'vulnerability identification', 'database querying', 'agile practices', 'innovation', 'software testing', 'test automation tools', 'product manager', 'iterative design', 'code coverage', 'design tools', 'security assessment', 'data analysis', 'consistency in design', 'information hierarchy', 'design guid ...
# 231

# %%
# make it a dataframe
unique_skills_df = pd.DataFrame(unique_skills, columns=['skill'])
# add id column, starting from 1
unique_skills_df['id'] = np.arange(len(unique_skills_df)) + 1
# reorder columns
unique_skills_df = unique_skills_df[['id', 'skill']]
unique_skills_df
# Out:
#       id                            skill
# 0      1                      code review
# 1      2  security incident response plan
# 2      3     software development process
# 3      4                   data analytics
# 4      5             code maintainability
# ..   ...                              ...
# 226  227                         metadata
# 227  228                     scrum master
# 228  229                  testing metrics
# 229  230                      data ethics
# 230  231                     code quality
#
# [231 rows x 2 columns]

# %%
# save to csv
unique_skills_df.to_csv('../../static/csv/skill_1.csv', index=False)

# %%
# load the csv file
unique_skills_df = pd.read_csv('../../static/csv/skill_1.csv')

# %%
skill_mapping = unique_skills_df.set_index('skill')['id'].to_dict()

# %%
skill_mapping
# Out:
# {'security analyst': 1,
#  'authentication': 2,
#  'ui/ux design software': 3,
#  'product manager': 4,
#  'testing techniques': 5,
#  'content organization': 6,
#  'data analysis': 7,
#  'authentication methods': 8,
#  'user centered design': 9,
#  'penetration testing': 10,
#  'data protection': 11,
#  'testing methods': 12,
#  'mvp': 13,
#  'sql': 14,
#  'scrum master': 15,
#  'lean startup': 16,
#  'role of a software architect': 17,
#  'design ethics': 18,
#  'defect detection': 19,
#  'black box testing': 20,
#  'software development lifecycle': 21,
#  'feature prioritization': 22,
#  'statistical analysis': 23,
#  'unit testing': 24,
#  'security incident handling': 25,
#  'acceptance criteria': 26,
#  'android development': 27,
#  'color psychology': 28,
#  'devops': 29,
#  'information hierarchy': 30,
#  'data management': 31,
#  'inclusive design': 32,
#  'design guidelines': 33,
#  'usability testing': 34,
#  'software architecture': 35,
#  'nosql': 36,
#  'agile development': 37,
#  'testing existing functionality': 38,
#  'user feedback': 39,
#  'visual perception': 40,
#  'data visualization': 41,
#  'database management': 42,
#  'restful api': 43,
#  'biometric authentication': 44,
#  'quality assurance': 45,
#  'testing changes': 46,
#  'complementary colors': 47,
#  'test automation tools': 48,
#  'testing metrics': 49,
#  'prototyping': 50,
#  'user experience': 51,
#  'risk taking': 52,
#  'design tools': 53,
#  'ethical data use': 54,
#  'ui/ux design': 55,
#  'code review': 56,
#  'agile principles': 57,
#  'cybersecurity': 58,
#  'product launch': 59,
#  'responsible ai': 60,
#  'data cleaning': 61,
#  'software development': 62,
#  'stress testing': 63,
#  'performance evaluation': 64,
#  'product management': 65,
#  'device protection': 66,
#  'user interface': 67,
#  'code coverage': 68,
#  'user experience testing': 69,
#  'cross platform testing': 70,
#  'user acceptance testing': 71,
#  'automation': 72,
#  'product roadmap': 73,
#  'identity verification': 74,
#  'data quality': 75,
#  'vulnerability identification': 76,
#  'pattern recognition': 77,
#  'testing phases': 78,
#  'iterative development': 79,
#  'learning culture': 80,
#  'big data': 81,
#  'information security': 82,
#  'performance testing': 83,
#  'lean product development': 84,
#  'environment compatibility': 85,
#  'product development': 86,
#  'scrum framework': 87,
#  'adaptability in development': 88,
#  'svn': 89,
#  'two factor authentication': 90,
#  'statistics': 91,
#  'color theory': 92,
#  'wireframing': 93,
#  'authorization': 94,
#  'ci/cd': 95,
#  'agile software development': 96,
#  'data science': 97,
#  'usability evaluation': 98,
#  'information security compliance': 99,
#  'data dashboards': 100,
#  'vulnerability management': 101,
#  'testing processes': 102,
#  'web services': 103,
#  'knowledge transfer': 104,
#  'security principles': 105,
#  'agile methodology': 106,
#  'typography': 107,
#  'stakeholder collaboration': 108,
#  'technical writer': 109,
#  'exploratory data analysis': 110,
#  'software testing': 111,
#  'user verification': 112,
#  'organizational security': 113,
#  'git': 114,
#  'agile manifesto': 115,
#  'code quality': 116,
#  'data processing': 117,
#  'information architecture': 118,
#  'access control': 119,
#  'load testing': 120,
#  'lean thinking': 121,
#  'social engineering': 122,
#  'security assessment': 123,
#  'data preprocessing': 124,
#  'api design': 125,
#  'collaborative development': 126,
#  'api': 127,
#  'iterative design': 128,
#  'interaction design': 129,
#  'version control': 130,
#  'security controls': 131,
#  'software quality assurance': 132,
#  'model performance': 133,
#  'software development life cycle': 134,
#  'code reusability': 135,
#  'tableau': 136,
#  'machine learning': 137,
#  'incident management': 138,
#  'web design': 139,
#  'empathy in design': 140,
#  'collaboration': 141,
#  'continuous integration': 142,
#  'mobile responsiveness': 143,
#  'endpoint security': 144,
#  'data scientist': 145,
#  'software integration': 146,
#  'product owner': 147,
#  'brand identity': 148,
#  'data governance': 149,
#  'java programming': 150,
#  'data ethics': 151,
#  'information manipulation': 152,
#  'build stability': 153,
#  'data analytics': 154,
#  'software development practices': 155,
#  'cybersecurity threats': 156,
#  'compatibility testing': 157,
#  'smoke testing': 158,
#  'object oriented design': 159,
#  'user navigation': 160,
#  'user personas': 161,
#  'automated testing': 162,
#  'test comprehensiveness': 163,
#  'emotional design': 164,
#  'regression testing': 165,
#  'product goals': 166,
#  'a/b testing': 167,
#  'fail cheap': 168,
#  'security measures': 169,
#  'graphic design': 170,
#  'customer feedback': 171,
#  'user interface design': 172,
#  'usability principles': 173,
#  'product success': 174,
#  'median': 175,
#  'documentation': 176,
#  'solid principles': 177,
#  'visual communication': 178,
#  'consistency in design': 179,
#  'code maintainability': 180,
#  'security policy': 181,
#  'interactive design': 182,
#  'mobile app development': 183,
#  'design principles': 184,
#  'user experience optimization': 185,
#  'data dictionary': 186,
#  'data security': 187,
#  'threat mitigation': 188,
#  'feature evaluation': 189,
#  'scrum': 190,
#  'design process': 191,
#  'dry principle': 192,
#  'software development process': 193,
#  'exploratory testing': 194,
#  'privacy': 195,
#  'experimentation': 196,
#  'testing efficiency': 197,
#  'software development principles': 198,
#  'database querying': 199,
#  'continuous improvement': 200,
#  'network security': 201,
#  'account security': 202,
#  'user testing': 203,
#  'phishing attacks': 204,
#  'security incident response plan': 205,
#  'identity management': 206,
#  'accessibility': 207,
#  'source code management': 208,
#  'ux design': 209,
#  'color schemes': 210,
#  'product documentation': 211,
#  'user interfaces': 212,
#  'animation': 213,
#  'feature engineering': 214,
#  'metadata': 215,
#  'scrum roles': 216,
#  'defect identification': 217,
#  'innovation': 218,
#  'data driven decision making': 219,
#  'compliance': 220,
#  'predictive modeling': 221,
#  'product backlog': 222,
#  'fail fast': 223,
#  'product strategy': 224,
#  'usability': 225,
#  'testing extremes': 226,
#  'responsive design': 227,
#  'product planning': 228,
#  'agile practices': 229,
#  'test engineer': 230,
#  'motion design': 231}

# %%
df['skills_list'] = df['skills_list'].apply(lambda skills: [skill_mapping.get(skill) for skill in skills if skill in skill_mapping])
df.head()
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
# 3            4  What does the term "API" stand for in software...
# 4            5  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
# 3  ['Application Programming Interface','Advanced...               0
# 4  ['To test individual components or functions',...               0
#
#    field_id      skills_list
# 0         1  [130, 208, 126]
# 1         1  [198, 192, 135]
# 2         1   [27, 150, 183]
# 3         1  [127, 146, 103]
# 4         1   [24, 111, 116]

# %%
test_df = df.explode('skills_list')
# get only question_id and skills_list
test_df = test_df[['question_id', 'skills_list']]
test_df
# Out:
#     question_id skills_list
# 0             1         130
# 0             1         208
# 0             1         126
# 1             2         198
# 1             2         192
# ..          ...         ...
# 88           89         163
# 89           90         157
# 89           90         132
# 89           90          70
# 89           90          85
#
# [331 rows x 2 columns]

# %%
test_df = test_df.rename(columns={'skills_list': 'skill_id'})
test_df
# Out:
#     question_id skill_id
# 0             1      130
# 0             1      208
# 0             1      126
# 1             2      198
# 1             2      192
# ..          ...      ...
# 88           89      163
# 89           90      157
# 89           90      132
# 89           90       70
# 89           90       85
#
# [331 rows x 2 columns]

# %%
# add test_skill_id column
test_df['id'] = np.arange(len(test_df)) + 1
test_df
# Out:
#     question_id skill_id   id
# 0             1      130    1
# 0             1      208    2
# 0             1      126    3
# 1             2      198    4
# 1             2      192    5
# ..          ...      ...  ...
# 88           89      163  327
# 89           90      157  328
# 89           90      132  329
# 89           90       70  330
# 89           90       85  331
#
# [331 rows x 3 columns]

# %%
# reorder columns
test_df = test_df[['id', 'question_id', 'skill_id']]
test_df
# Out:
#      id  question_id skill_id
# 0     1            1      130
# 0     2            1      208
# 0     3            1      126
# 1     4            2      198
# 1     5            2      192
# ..  ...          ...      ...
# 88  327           89      163
# 89  328           90      157
# 89  329           90      132
# 89  330           90       70
# 89  331           90       85
#
# [331 rows x 3 columns]

# %%
# save to csv
test_df.to_csv('../../static/csv/assessment_test_skills_2.csv', index=False)

# %%
df = pd.read_csv('../../static/csv/assessment_test_skills_2.csv')
df.head()
# Out:
#    id  question_id  skill_id
# 0   1            1       130
# 1   2            1       208
# 2   3            1       126
# 3   4            2       198
# 4   5            2       192

# %%
df.tail()
# Out:
#       id  test_id  skill_id
# 326  327       89       163
# 327  328       90       157
# 328  329       90       132
# 329  330       90        70
# 330  331       90        85

# %%
# # reodercolumns
# df = df[['id', 'skill_id','test_id' ]]
# df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\aky\AppData\Local\Programs\Python\Python38\course_test\course-u\course_u\src\notebooks\unique_skills.ipynb Cell 20 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/aky/AppData/Local/Programs/Python/Python38/course_test/course-u/course_u/src/notebooks/unique_skills.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # reodercolumns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/aky/AppData/Local/Programs/Python/Python38/course_test/course-u/course_u/src/notebooks/unique_skills.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> df = df[['id', 'skill_id','test_id' ]]
#       <a href='vscode-notebook-cell:/c%3A/Users/aky/AppData/Local/Programs/Python/Python38/course_test/course-u/course_u/src/notebooks/unique_skills.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> df.head()
#
# File c:\Users\aky\AppData\Local\Programs\Python\Python38\datasci\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\aky\AppData\Local\Programs\Python\Python38\datasci\lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File c:\Users\aky\AppData\Local\Programs\Python\Python38\datasci\lib\site-packages\pandas\core\indexes\base.py:5941, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['test_id'] not in index"

# %%
# rename column question_id to test_id
df = df.rename(columns={'question_id': 'test_id'})

# %%
# save to csv
df.to_csv('../../static/csv/assessment_test_skills.csv', index=False)

# %% [markdown]
# # For Test_3, that have more test questions

# %%
import pandas as pd
import numpy as np
import ast

# %%
df = pd.read_csv('../../static/csv/test_3.csv')
df.head(2)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
#
#    field_id                                        skills_list
# 0         1  ['version control', 'source code management', ...
# 1         1  ['software development principles', 'dry princ...

# %%
df2 = pd.read_csv('../../static/csv/test_4.csv')
df2.head(2)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
#
#                                              options  correct_option  \
# 0  ["To track changes in code", "To format text",...               0
# 1  ["Don"t Repeat Yourself", "Design Reusable Yie...               0
#
#    field_id                                        skills_list
# 0         1  ['Version Control','Source Code Management','C...
# 1         1  ["Software Development Principles","DRY Princi...

# %%
# on options column replace ' wtih ""
df2['options'] = df2['options'].apply(lambda x: x.replace("'", '"'))
df2.head(2)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
#
#                                              options  correct_option  \
# 0  ["To track changes in code", "To format text",...               0
# 1  ["Don"t Repeat Yourself", "Design Reusable Yie...               0
#
#    field_id                                        skills_list
# 0         1  ['Version Control','Source Code Management','C...
# 1         1  ['Software Development Principles','DRY Princi...

# %%
# remove columns kills_list
df2 = df2.drop(columns=['skills_list'])

# %%
df2.head(2)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
#
#                                              options  correct_option  field_id
# 0  ["To track changes in code", "To format text",...               0         1
# 1  ["Don"t Repeat Yourself", "Design Reusable Yie...               0         1

# %%
# convert options to JSON format
import json
# make to JSON string
df2['options'] = df2['options'].apply(lambda x: json.dumps(x))
df2.head(2)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
#
#                                              options  correct_option  field_id
# 0  "[\"To track changes in code\", \"To format te...               0         1
# 1  "[\"Don\"t Repeat Yourself\", \"Design Reusabl...               0         1

# %%
# save to csv
df2.to_csv('../../static/csv/assessment_test.csv', index=False)

# %%
# Convert the string representation of lists into actual lists
df['skills_list'] = df['skills_list'].apply(ast.literal_eval)
df.head(3)
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
#
#    field_id                                        skills_list
# 0         1  [version control, source code management, coll...
# 1         1  [software development principles, dry principl...
# 2         1  [android development, java programming, mobile...

# %%
# to lower case
df['skills_list'] = df['skills_list'].apply(lambda x: [y.lower() for y in x])
df.head()
# Out:
#    question_id                                           question  \
# 0            1  What is the purpose of a version control syste...
# 1            2   What does DRY stand for in software development?
# 2            3  Which programming language is known for its us...
# 3            4  What does the term "API" stand for in software...
# 4            5  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ['To track changes in code', 'To format text',...               0
# 1  ['Don't Repeat Yourself', 'Design Reusable Yie...               0
# 2                  ['Java', 'Python', 'Ruby', 'C++']               0
# 3  ['Application Programming Interface','Advanced...               0
# 4  ['To test individual components or functions',...               0
#
#    field_id                                        skills_list
# 0         1  [version control, source code management, coll...
# 1         1  [software development principles, dry principl...
# 2         1  [android development, java programming, mobile...
# 3         1          [api, software integration, web services]
# 4         1     [unit testing, software testing, code quality]

# %%
# remove strings 'skills' and 'skill'
df['skills_list'] = df['skills_list'].apply(lambda x: [y.replace('skills', '') for y in x])
df['skills_list'] = df['skills_list'].apply(lambda x: [y.replace('skill', '') for y in x])

# %%
# strip
df['skills_list'] = df['skills_list'].apply(lambda x: [y.strip() for y in x])
# replace '-' to ' '
df['skills_list'] = df['skills_list'].apply(lambda x: [y.replace('-', ' ') for y in x])

# %%
# remove empty
df['skills_list'] = df['skills_list'].apply(lambda x: [y for y in x if y != ''])

# %%
# Create a list of skills by combining all the skills from the 'skills_list' column
all_skills = [skill for skills_list in df['skills_list'] for skill in skills_list]

# Now, 'all_skills' contains all the skills from the DataFrame
print(all_skills)
# Out:
# ['version control', 'source code management', 'collaborative development', 'software development principles', 'dry principle', 'code reusability', 'android development', 'java programming', 'mobile app development', 'api', 'software integration', 'web services', 'unit testing', 'software testing', 'code quality', 'data cleaning', 'data preprocessing', 'data analysis', 'data visualization', 'data analytics', 'data dashboards', 'tableau', 'data visualization', 'data analytics', 'data dashboards', 'tableau', 'sql', 'database querying', 'database management', 'statistics', 'median', 'data analysis', 'design principles', 'consistency in design', 'user interface design', 'color theory', 'complementary colors', 'color schemes', 'user testing', 'user experience testing', 'usability evaluation', 'design tools', 'wireframing', 'prototyping', 'ui/ux design software', 'product management', 'product manager', 'feature prioritization', 'product roadmap', 'product planning', 'product strategy', 'agile methodology', 'iterative development', 'customer feedback', 'scrum', 'product strategy', 'product documentation', 'product goals', 'mvp', 'product development', 'product launch', 'software testing', 'quality assurance', 'defect detection', 'regression testing', 'software testing', 'testing changes', 'load testing', 'software testing', 'performance testing', 'usability testing', 'user experience testing', 'user centered design', 'usability testing', 'user experience testing', 'user centered design', 'usability testing', 'user experience testing', 'user centered design', 'identity verification', 'authentication', 'access control', 'identity verification', 'authentication', 'access control', 'identity verification', 'authentication', 'access control', 'access control', 'security principles', 'authorization', 'access control', 'security principles', 'authorization', 'version control', 'git', 'svn', 'source code management', 'git', 'version control', 'collaborative development', 'code review', 'software development', 'collaborative development', 'continuous integration', 'ci/cd', 'software development practices', 'software architecture', 'software development', 'role of a software architect', 'devops', 'collaboration', 'continuous integration', 'software development practices', 'restful api', 'web services', 'api design', 'software development', 'agile software development', 'agile manifesto', 'scrum', 'software development principles', 'scrum framework', 'product owner', 'agile development', 'scrum roles', 'solid principles', 'object oriented design', 'software architecture', 'code maintainability', 'exploratory data analysis', 'data science', 'data analysis', 'statistical analysis', 'data preprocessing', 'machine learning', 'feature engineering', 'model performance', 'data dictionary', 'database management', 'metadata', 'data governance', 'big data', 'data processing', 'data analytics', 'nosql', 'data scientist', 'data analysis', 'predictive modeling', 'data driven decision making', 'data governance', 'data management', 'data quality', 'compliance', 'machine learning', 'data analysis', 'predictive modeling', 'pattern recognition', 'a/b testing', 'experimentation', 'data driven decision making', 'statistical analysis', 'data ethics', 'ethical data use', 'privacy', 'responsible ai', 'data security', 'data management', 'information security', 'cybersecurity', 'typography', 'graphic design', 'visual communication', 'brand identity', 'responsive design', 'user experience', 'web design', 'mobile responsiveness', 'information architecture', 'web design', 'user navigation', 'content organization', 'color psychology', 'design principles', 'emotional design', 'visual perception', 'motion design', 'user interfaces', 'interactive design', 'animation', 'user personas', 'user centered design', 'ux design', 'empathy in design', 'accessibility', 'inclusive design', 'usability', 'design ethics', 'prototyping', 'design process', 'user testing', 'iterative design',  ...

# %%
len(all_skills)
# Out:
# 231

# %%
# remove duplicates
all_skills = list(set(all_skills))

# %% [markdown]
# ### Since all skils are similar to current skills from before, we don't need to add it on the skill list

# %% [markdown]
# lets check if there are any unique skills from this

# %%
# load skill_4.csv
skill_df = pd.read_csv('../../static/csv/skill_4.csv')

# %%
# into list
skill_list = skill_df['skill'].tolist()

# %%
# get sample 
sample = np.random.choice(skill_list, 10)
print(sample)
# Out:
# ['data conversion' 'executive management' 'unix administration'
#  'dreamweaver' 'ux' 'web application developer' 'communication' 'prime'
#  'system admin' 'sap scripts']

# %%
# check if there are skills from all_skills that are not in skill_list
for skill in all_skills:
    if skill not in skill_list:
        print(skill)

# %%
# get unique skills that are not in skill_list
unique_skills = [skill for skill in all_skills if skill not in skill_list]
print(unique_skills)
# Out:
# []

# %%
skill_mapping = skill_df.set_index('skill')['id'].to_dict()

# %%
df.sample(3)
# Out:
#     question_id                                           question  \
# 68           69  How does DevOps contribute to the software dev...
# 40           41  What is the importance of exploratory data ana...
# 83           84  Define the term 'Stress Testing' in the contex...
#
#                                           description  \
# 68  Explain the principles and benefits of integra...
# 40  Explain the significance of exploratory data a...
# 83  Explain what Stress Testing involves and its s...
#
#                                               options  correct_option  \
# 68  ['Facilitates collaboration between developmen...               0
# 40  ['Gain insights into data distributions and pa...               0
# 83  ['Assesses software behavior under extreme con...               0
#
#     field_id                                        skills_list
# 68         4  [devops, software development lifecycle, conti...
# 40         2  [exploratory data analysis, data science, data...
# 83         5  [stress testing, software quality assurance, p...

# %%
# apply skill_mapping to skills_list
df['skills_list'] = df['skills_list'].apply(lambda skills: [skill_mapping.get(skill) for skill in skills if skill in skill_mapping])
df.sample(3)

# %%
# explode skills_list
df = df.explode('skills_list')

# %%
# get only question_id and skills_list
df = df[['question_id', 'skills_list']]
df.head()
# Out:
#    question_id skills_list
# 0            1         130
# 0            1         208
# 0            1         126
# 1            2         198
# 1            2         192

# %%
# rename
df = df.rename(columns={'skills_list': 'skill_id'})
df.head()
# Out:
#    question_id skill_id
# 0            1      130
# 0            1      208
# 0            1      126
# 1            2      198
# 1            2      192

# %%
# add skill_id column
df['id'] = np.arange(len(df)) + 1
df.head()
# Out:
#    question_id skill_id  id
# 0            1      130   1
# 0            1      208   2
# 0            1      126   3
# 1            2      198   4
# 1            2      192   5

# %%
# reorder columns
df = df[['id', 'question_id', 'skill_id']]
df.head()
# Out:
#    id  question_id skill_id
# 0   1            1      130
# 0   2            1      208
# 0   3            1      126
# 1   4            2      198
# 1   5            2      192

# %%
# sve to csv
df.to_csv('../../static/csv/assessment_test_skills.csv', index=False)
