# %%
import pandas as pd
import numpy as np

# %%
coursera = pd.read_csv('../../static/csv/coursera.csv')
coursera
# Out:
#                                             Course Name  \
# 0     Write A Feature Length Screenplay For Film Or ...
# 1     Business Strategy: Business Model Canvas Analy...
# 2                         Silicon Thin Film Solar Cells
# 3                                  Finance for Managers
# 4          Retrieve Data using Single-Table SQL Queries
# ...                                                 ...
# 3517  Capstone: Retrieving, Processing, and Visualiz...
# 3518                   Patrick Henry: Forgotten Founder
# 3519  Business intelligence and data analytics: Gene...
# 3520                                Rigid Body Dynamics
# 3521  Architecting with Google Kubernetes Engine: Pr...
#
#                                              University Difficulty Level  \
# 0                             Michigan State University         Beginner
# 1                              Coursera Project Network         Beginner
# ...

# %%
coursera = coursera[coursera['field_id'] != 0]
coursera
# Out:
#                                             Course Name  \
# 4          Retrieve Data using Single-Table SQL Queries
# 5     Building Test Automation Framework using Selen...
# 7                         Programming Languages, Part A
# 12                                 Hacking and Patching
# 13            Business Statistics and Analysis Capstone
# ...                                                 ...
# 3448                               Finance for Startups
# 3450  Networking and Security Architecture with VMwa...
# 3464                Big Data Integration and Processing
# 3478                        Security Awareness Training
# 3519  Business intelligence and data analytics: Gene...
#
#                                              University Difficulty Level  \
# 4                              Coursera Project Network         Beginner
# 5                              Coursera Project Network         Beginner
# ...

# %%
# remove columns
coursera.drop(columns=['skills_list', 'keywords', 'skill_list_2', 'skill_list_3'], inplace=True)
coursera
# Out:
# C:\Users\aky\AppData\Local\Temp\ipykernel_15684\2202422164.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coursera.drop(columns=['skills_list', 'keywords', 'skill_list_2', 'skill_list_3'], inplace=True)
#                                             Course Name  \
# 4          Retrieve Data using Single-Table SQL Queries
# 5     Building Test Automation Framework using Selen...
# 7                         Programming Languages, Part A
# 12                                 Hacking and Patching
# 13            Business Statistics and Analysis Capstone
# ...                                                 ...
# 3448                               Finance for Startups
# 3450  Networking and Security Architecture with VMwa...
# 3464                Big Data Integration and Processing
# ...

# %%
# save to csv
coursera.to_csv('../../static/csv/coursera_small.csv', index=False)

# %%
coursera = pd.read_csv('../../static/csv/coursera_small.csv')
coursera
# Out:
#                                            Course Name  \
# 0         Retrieve Data using Single-Table SQL Queries
# 1    Building Test Automation Framework using Selen...
# 2                        Programming Languages, Part A
# 3                                 Hacking and Patching
# 4            Business Statistics and Analysis Capstone
# ..                                                 ...
# 189                               Finance for Startups
# 190  Networking and Security Architecture with VMwa...
# 191                Big Data Integration and Processing
# 192                        Security Awareness Training
# 193  Business intelligence and data analytics: Gene...
#
#                                             University Difficulty Level  \
# 0                             Coursera Project Network         Beginner
# 1                             Coursera Project Network         Beginner
# 2                             University of Washington     Intermediate
# ...

# %%
# rename columns
# title, university, level, rating, url, description, skills
coursera.rename(columns={'Course Name':'title', 'University':'university', 'Difficulty Level':'level', 'Course Rating':'rating', 'Course URL':'url', 'Course Description':'description', 'Skills':'skills'}, inplace=True)

# %%
coursera.head(2)
# Out:
#                                                title  \
# 0       Retrieve Data using Single-Table SQL Queries
# 1  Building Test Automation Framework using Selen...
#
#                  university     level rating  \
# 0  Coursera Project Network  Beginner    4.6
# 1  Coursera Project Network  Beginner    4.7
#
#                                                  url  \
# 0  https://www.coursera.org/learn/single-table-sq...
# 1  https://www.coursera.org/learn/building-test-a...
#
#                                          description  \
# 0  In this course you�ll learn how to effectively...
# 1  Selenium is one of the most widely used functi...
#
#                                               skills  field_id
# 0  Data Analysis  select (sql)  database manageme...         2
# 1  maintenance  test case  test automation  scree...         5

# %%
# add material_id column + 1
coursera['material_id'] = coursera.index + 1
coursera
# Out:
#                                                  title  \
# 0         Retrieve Data using Single-Table SQL Queries
# 1    Building Test Automation Framework using Selen...
# 2                        Programming Languages, Part A
# 3                                 Hacking and Patching
# 4            Business Statistics and Analysis Capstone
# ..                                                 ...
# 189                               Finance for Startups
# 190  Networking and Security Architecture with VMwa...
# 191                Big Data Integration and Processing
# 192                        Security Awareness Training
# 193  Business intelligence and data analytics: Gene...
#
#                                             university         level rating  \
# 0                             Coursera Project Network      Beginner    4.6
# 1                             Coursera Project Network      Beginner    4.7
# ...

# %%
# reorder columns
coursera = coursera[['material_id', 'title', 'university', 'level', 'rating', 'url', 'description', 'skills','field_id']]
coursera
# Out:
#      material_id                                              title  \
# 0              1       Retrieve Data using Single-Table SQL Queries
# 1              2  Building Test Automation Framework using Selen...
# 2              3                      Programming Languages, Part A
# 3              4                               Hacking and Patching
# 4              5          Business Statistics and Analysis Capstone
# ..           ...                                                ...
# 189          190                               Finance for Startups
# 190          191  Networking and Security Architecture with VMwa...
# 191          192                Big Data Integration and Processing
# 192          193                        Security Awareness Training
# 193          194  Business intelligence and data analytics: Gene...
#
#                                             university         level rating  \
# ...

# %%
# save to csv
coursera.to_csv('../../static/csv/website_learningmaterial.csv', index=False)
