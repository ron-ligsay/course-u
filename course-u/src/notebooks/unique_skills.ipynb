# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../static/csv/test_.csv')
df
# Out:
#     question_id  field_id                                           question  \
# 0             1         1  What is the purpose of a version control syste...
# 1             2         1   What does DRY stand for in software development?
# 2             3         1  Which programming language is known for its us...
# 3             4         1  What does the term "API" stand for in software...
# 4             5         1  What is the primary purpose of unit testing in...
# 5             6         2  What is the process of cleaning and organizing...
# 6             7         2  Which data visualization tool is often used to...
# 7             8         2  What type of analysis aims to discover pattern...
# 8             9         2  What does SQL stand for in the context of data...
# 9            10         2  Which statistical measure represents the middl...
# 10           11         3  What does "UI" stand for in the context of des...
# 11           12         3  What design principle emphasizes consistency i...
# 12           13         3  Which color combination involves two colors op...
# 13           14         3  What is the primary goal of user testing in UX...
# 14           15         3  Which design tool is often used for creating w...
# 15           16         4  What role is responsible for defining and prio...
# 16           17         4  What is a product roadmap commonly used for in...
# 17           18         4  What methodology emphasizes iterative developm...
# 18           19         4  What document outlines the goals, strategies, ...
# 19           20         4  What does MVP stand for in the context of prod...
# 20           21         5  What type of testing aims to find defects or i...
# 21           22         5  What does the term "Regression Testing" refer ...
# 22           23         5  What is the purpose of "Load Testing" in softw...
# 23           24         5  Which testing technique involves intentionally...
# 24           25         5  What is the primary focus of "Usability Testin...
# 25           26         6  What is the practice of disguising information...
# 26           27         6  What does "Phishing" refer to in the context o...
# 27           28         6  Which security measure involves confirming the...
# 28           29         6  What is a "Firewall" in the context of network...
# 29           30         6  Which security principle emphasizes providing ...
#
#                                           description  \
# 0   Select the most accurate answer related to ver...
# 1    Choose the correct expansion of the acronym DRY.
# 2   Identify the programming language commonly ass...
# 3               Select one option you think is right.
# 4          Select the main objective of unit testing.
# 5   Choose the correct term related to data prepar...
# 6   dentify the popular tool used for creating int...
# 7   Select the analysis method that focuses on dis...
# 8    Choose the correct expansion of the acronym SQL.
# 9   Identify the statistical measure related to th...
# 10    Choose the correct expansion of the acronym UI.
# 11  Select the design principle that focuses on ma...
# 12  Identify the color combination defined by colo...
# 13  Choose the main objective of conducting user t...
# 14  Identify the design tool frequently used for w...
# 15  Select the role that focuses on feature defini...
# 16  What is a product roadmap commonly used for in...
# 17  Select the methodology focused on iterative de...
# 18  Choose the document that defines product goals...
# 19   Choose the correct expansion of the acronym MVP.
# 20  Select the type of testing focused on identify...
# 21  Choose the correct definition of regression te...
# 22         Select the main objective of load testing.
# 23  Which testing technique involves intentionally...
# 24  Choose the primary area of focus for usability...
# 25  Select the security practice that involves dis...
# 26  What does "Phishing" refer to in the context o...
# 27  Identify the security practice related to user...
# 28       Choose the correct definition of a firewall.
# 29  Select the security principle focused on acces...
#
#                                               options  correct_option  \
# 0   ["To track changes in code", "To format text",...               0
# 1   ["Don't Repeat Yourself", "Design Reusable Yie...               0
# 2                   ["Java", "Python", "Ruby", "C++"]               0
# 3   ["Application Programming Interface", "Advance...               0
# 4   ["To test individual components or functions",...               0
# 5   ["Data Wrangling", "Data Elevation", "Data Shr...               0
# 6   ["Tableau", "Microsoft Word", "Adobe Photoshop...               0
# 7   ["Data Mining", "Data Storage", "Data Deletion...               0
# 8   ["Structured Query Language", "Simple Query Lo...               0
# 9                 ["Median", "Mean", "Mode", "Range"]               0
# 10  ["User Interface", "Universal Integration", "U...               0
# 11  ["Consistency", "Chaos", "Innovation", "Random...               0
# 12  ["Complementary Colors", "Primary Colors", "An...               0
# 13  ["To gather feedback from users", "To choose c...               0
# 14  ["Sketch", "Microsoft Excel", "Adobe Illustrat...               0
# 15  ["Product Manager", "Sales Representative", "G...               0
# 16  ["To communicate product plans", "To create sa...               0
# 17       ["Agile", "Waterfall", "Six Sigma", "Scrum"]               0
# 18  ["Product Strategy Document", "Product Marketi...               0
# 19  ["Minimum Viable Product", "Maximum Valuable P...               0
# 20  ["Quality Assurance Testing", "User Acceptance...               0
# 21  ["Testing to ensure new changes don't break ex...               0
# 22  ["To evaluate system performance under heavy l...               0
# 23  ["Fuzz Testing", "Stress Testing", "Smoke Test...               0
# 24  ["User Experience and Interface Usability", "L...               0
# 25  ["Encryption", "Decryption", "Authentication",...               0
# 26  ["A type of cyberattack aimed at tricking user...               0
# 27  ["Authentication", "Authorization", "Firewall"...               0
# 28  ["A network security device that filters and m...               0
# 29  ["Authorization", "Authentication", "Intrusion...               0
#
#                                           skills_list
# 0   ["Version Control", "Source Code Management", ...
# 1   ["Software Development Principles", "DRY (Don'...
# 2   ["Android Development", "Java Programming", "M...
# 3   ["API (Application Programming Interface)", "S...
# 4   ["Unit Testing", "Software Testing", "Code Qua...
# 5   ["Data Cleaning", "Data Preprocessing", "Data ...
# 6   ["Data Visualization", "Data Analytics", "Data...
# 7   ["Data Visualization", "Data Analytics", "Data...
# 8   ["SQL (Structured Query Language)", "Database ...
# 9           ["Statistics", "Median", "Data Analysis"]
# 10  ["Design Principles", "Consistency in Design",...
# 11  ["Color Theory", "Complementary Colors", "Colo...
# 12  ["User Testing", "User Experience Testing", "U...
# 13  ["Design Tools", "Wireframing", "Prototyping",...
# 14  ["Product Management", "Product Manager", "Fea...
# 15  ["Product Roadmap", "Product Planning", "Produ...
# 16  ["Agile Methodology", "Iterative Development",...
# 17  ["Product Strategy", "Product Documentation", ...
# 18  ["MVP (Minimum Viable Product)", "Product Deve...
# 19  ["Software Testing", "Quality Assurance", "Def...
# 20  ["Regression Testing", "Software Testing", "Te...
# 21  ["Load Testing", "Software Testing", "Performa...
# 22  ["Usability Testing", "User Experience Testing...
# 23  ["Usability Testing", "User Experience Testing...
# 24  ["Usability Testing", "User Experience Testing...
# 25  ["Identity Verification", "Authentication", "A...
# 26  ["Identity Verification", "Authentication", "A...
# 27  ["Identity Verification", "Authentication", "A...
# 28  ["Access Control", "Security Principles", "Aut...
# 29  ["Access Control", "Security Principles", "Aut...

# %%
import ast
# Convert the string representation of lists into actual lists
df['skills_list'] = df['skills_list'].apply(ast.literal_eval)
df
# Out:
#     question_id  field_id                                           question  \
# 0             1         1  What is the purpose of a version control syste...
# 1             2         1   What does DRY stand for in software development?
# 2             3         1  Which programming language is known for its us...
# 3             4         1  What does the term "API" stand for in software...
# 4             5         1  What is the primary purpose of unit testing in...
# 5             6         2  What is the process of cleaning and organizing...
# 6             7         2  Which data visualization tool is often used to...
# 7             8         2  What type of analysis aims to discover pattern...
# 8             9         2  What does SQL stand for in the context of data...
# 9            10         2  Which statistical measure represents the middl...
# 10           11         3  What does "UI" stand for in the context of des...
# 11           12         3  What design principle emphasizes consistency i...
# 12           13         3  Which color combination involves two colors op...
# 13           14         3  What is the primary goal of user testing in UX...
# 14           15         3  Which design tool is often used for creating w...
# 15           16         4  What role is responsible for defining and prio...
# 16           17         4  What is a product roadmap commonly used for in...
# 17           18         4  What methodology emphasizes iterative developm...
# 18           19         4  What document outlines the goals, strategies, ...
# 19           20         4  What does MVP stand for in the context of prod...
# 20           21         5  What type of testing aims to find defects or i...
# 21           22         5  What does the term "Regression Testing" refer ...
# 22           23         5  What is the purpose of "Load Testing" in softw...
# 23           24         5  Which testing technique involves intentionally...
# 24           25         5  What is the primary focus of "Usability Testin...
# 25           26         6  What is the practice of disguising information...
# 26           27         6  What does "Phishing" refer to in the context o...
# 27           28         6  Which security measure involves confirming the...
# 28           29         6  What is a "Firewall" in the context of network...
# 29           30         6  Which security principle emphasizes providing ...
#
#                                           description  \
# 0   Select the most accurate answer related to ver...
# 1    Choose the correct expansion of the acronym DRY.
# 2   Identify the programming language commonly ass...
# 3               Select one option you think is right.
# 4          Select the main objective of unit testing.
# 5   Choose the correct term related to data prepar...
# 6   dentify the popular tool used for creating int...
# 7   Select the analysis method that focuses on dis...
# 8    Choose the correct expansion of the acronym SQL.
# 9   Identify the statistical measure related to th...
# 10    Choose the correct expansion of the acronym UI.
# 11  Select the design principle that focuses on ma...
# 12  Identify the color combination defined by colo...
# 13  Choose the main objective of conducting user t...
# 14  Identify the design tool frequently used for w...
# 15  Select the role that focuses on feature defini...
# 16  What is a product roadmap commonly used for in...
# 17  Select the methodology focused on iterative de...
# 18  Choose the document that defines product goals...
# 19   Choose the correct expansion of the acronym MVP.
# 20  Select the type of testing focused on identify...
# 21  Choose the correct definition of regression te...
# 22         Select the main objective of load testing.
# 23  Which testing technique involves intentionally...
# 24  Choose the primary area of focus for usability...
# 25  Select the security practice that involves dis...
# 26  What does "Phishing" refer to in the context o...
# 27  Identify the security practice related to user...
# 28       Choose the correct definition of a firewall.
# 29  Select the security principle focused on acces...
#
#                                               options  correct_option  \
# 0   ["To track changes in code", "To format text",...               0
# 1   ["Don't Repeat Yourself", "Design Reusable Yie...               0
# 2                   ["Java", "Python", "Ruby", "C++"]               0
# 3   ["Application Programming Interface", "Advance...               0
# 4   ["To test individual components or functions",...               0
# 5   ["Data Wrangling", "Data Elevation", "Data Shr...               0
# 6   ["Tableau", "Microsoft Word", "Adobe Photoshop...               0
# 7   ["Data Mining", "Data Storage", "Data Deletion...               0
# 8   ["Structured Query Language", "Simple Query Lo...               0
# 9                 ["Median", "Mean", "Mode", "Range"]               0
# 10  ["User Interface", "Universal Integration", "U...               0
# 11  ["Consistency", "Chaos", "Innovation", "Random...               0
# 12  ["Complementary Colors", "Primary Colors", "An...               0
# 13  ["To gather feedback from users", "To choose c...               0
# 14  ["Sketch", "Microsoft Excel", "Adobe Illustrat...               0
# 15  ["Product Manager", "Sales Representative", "G...               0
# 16  ["To communicate product plans", "To create sa...               0
# 17       ["Agile", "Waterfall", "Six Sigma", "Scrum"]               0
# 18  ["Product Strategy Document", "Product Marketi...               0
# 19  ["Minimum Viable Product", "Maximum Valuable P...               0
# 20  ["Quality Assurance Testing", "User Acceptance...               0
# 21  ["Testing to ensure new changes don't break ex...               0
# 22  ["To evaluate system performance under heavy l...               0
# 23  ["Fuzz Testing", "Stress Testing", "Smoke Test...               0
# 24  ["User Experience and Interface Usability", "L...               0
# 25  ["Encryption", "Decryption", "Authentication",...               0
# 26  ["A type of cyberattack aimed at tricking user...               0
# 27  ["Authentication", "Authorization", "Firewall"...               0
# 28  ["A network security device that filters and m...               0
# 29  ["Authorization", "Authentication", "Intrusion...               0
#
#                                           skills_list
# 0   [Version Control, Source Code Management, Coll...
# 1   [Software Development Principles, DRY (Don't R...
# 2   [Android Development, Java Programming, Mobile...
# 3   [API (Application Programming Interface), Soft...
# 4      [Unit Testing, Software Testing, Code Quality]
# 5   [Data Cleaning, Data Preprocessing, Data Analy...
# 6   [Data Visualization, Data Analytics, Data Dash...
# 7   [Data Visualization, Data Analytics, Data Dash...
# 8   [SQL (Structured Query Language), Database Que...
# 9                 [Statistics, Median, Data Analysis]
# 10  [Design Principles, Consistency in Design, Use...
# 11  [Color Theory, Complementary Colors, Color Sch...
# 12  [User Testing, User Experience Testing, Usabil...
# 13  [Design Tools, Wireframing, Prototyping, UI/UX...
# 14  [Product Management, Product Manager, Feature ...
# 15  [Product Roadmap, Product Planning, Product St...
# 16  [Agile Methodology, Iterative Development, Cus...
# 17  [Product Strategy, Product Documentation, Prod...
# 18  [MVP (Minimum Viable Product), Product Develop...
# 19  [Software Testing, Quality Assurance, Defect D...
# 20  [Regression Testing, Software Testing, Testing...
# 21  [Load Testing, Software Testing, Performance T...
# 22  [Usability Testing, User Experience Testing, U...
# 23  [Usability Testing, User Experience Testing, U...
# 24  [Usability Testing, User Experience Testing, U...
# 25  [Identity Verification, Authentication, Access...
# 26  [Identity Verification, Authentication, Access...
# 27  [Identity Verification, Authentication, Access...
# 28  [Access Control, Security Principles, Authoriz...
# 29  [Access Control, Security Principles, Authoriz...

# %%
# Create a list of skills by combining all the skills from the 'skills_list' column
all_skills = [skill for skills_list in df['skills_list'] for skill in skills_list]

# Now, 'all_skills' contains all the skills from the DataFrame
print(all_skills)

# %%
# get unique skills
unique_skills = list(set(all_skills))
print(unique_skills)
# count the number of unique skills
print(len(unique_skills))
# Out:
# ['Software Integration', 'Database Management', "DRY (Don't Repeat Yourself) Principle", 'Mobile App Development', 'Usability Evaluation', 'Software Testing', 'Product Documentation', 'Web Services', 'Design Principles', 'Feature Prioritization', 'Authorization', 'User Testing', 'Data Visualization', 'Consistency in Design', 'Wireframing', 'Product Strategy', 'Customer Feedback', 'Data Preprocessing', 'Version Control', 'Code Quality', 'Color Theory', 'Access Control', 'Product Development', 'Software Development Principles', 'Scrum', 'Product Management', 'Product Roadmap', 'Color Schemes', 'Identity Verification', 'MVP (Minimum Viable Product)', 'Android Development', 'Median', 'Java Programming', 'Design Tools', 'Security Principles', 'Unit Testing', 'User Experience Testing', 'Complementary Colors', 'Data Analysis', 'Product Goals', 'Code Reusability', 'Statistics', 'Load Testing', 'User-Centered Design', 'Authentication', 'User Interface Design', 'Data Dashboards', 'Product Manager', 'Defect Detection', 'Performance Testing', 'SQL (Structured Query Language)', 'Usability Testing', 'Regression Testing', 'Source Code Management', 'API (Application Programming Interface)', 'Database Querying', 'Agile Methodology', 'Quality Assurance', 'Iterative Development', 'Data Cleaning', 'Prototyping', 'Product Launch', 'Tableau', 'Testing Changes', 'UI/UX Design Software', 'Product Planning', 'Collaborative Development', 'Data Analytics']
# 68

# %%
# make it a dataframe
unique_skills_df = pd.DataFrame(unique_skills, columns=['skill'])
# add id column, starting from 1
unique_skills_df['id'] = np.arange(len(unique_skills_df)) + 1
# reorder columns
unique_skills_df = unique_skills_df[['id', 'skill']]
unique_skills_df
# Out:
#     id                                  skill
# 0    1                   Software Integration
# 1    2                    Database Management
# 2    3  DRY (Don't Repeat Yourself) Principle
# 3    4                 Mobile App Development
# 4    5                   Usability Evaluation
# ..  ..                                    ...
# 63  64                        Testing Changes
# 64  65                  UI/UX Design Software
# 65  66                       Product Planning
# 66  67              Collaborative Development
# 67  68                         Data Analytics
#
# [68 rows x 2 columns]

# %%
# save to csv
unique_skills_df.to_csv('../../static/csv/skill.csv', index=False)

# %%
skill_mapping = unique_skills_df.set_index('skill')['id'].to_dict()

# %%
skill_mapping
# Out:
# {'Software Integration': 1,
#  'Database Management': 2,
#  "DRY (Don't Repeat Yourself) Principle": 3,
#  'Mobile App Development': 4,
#  'Usability Evaluation': 5,
#  'Software Testing': 6,
#  'Product Documentation': 7,
#  'Web Services': 8,
#  'Design Principles': 9,
#  'Feature Prioritization': 10,
#  'Authorization': 11,
#  'User Testing': 12,
#  'Data Visualization': 13,
#  'Consistency in Design': 14,
#  'Wireframing': 15,
#  'Product Strategy': 16,
#  'Customer Feedback': 17,
#  'Data Preprocessing': 18,
#  'Version Control': 19,
#  'Code Quality': 20,
#  'Color Theory': 21,
#  'Access Control': 22,
#  'Product Development': 23,
#  'Software Development Principles': 24,
#  'Scrum': 25,
#  'Product Management': 26,
#  'Product Roadmap': 27,
#  'Color Schemes': 28,
#  'Identity Verification': 29,
#  'MVP (Minimum Viable Product)': 30,
#  'Android Development': 31,
#  'Median': 32,
#  'Java Programming': 33,
#  'Design Tools': 34,
#  'Security Principles': 35,
#  'Unit Testing': 36,
#  'User Experience Testing': 37,
#  'Complementary Colors': 38,
#  'Data Analysis': 39,
#  'Product Goals': 40,
#  'Code Reusability': 41,
#  'Statistics': 42,
#  'Load Testing': 43,
#  'User-Centered Design': 44,
#  'Authentication': 45,
#  'User Interface Design': 46,
#  'Data Dashboards': 47,
#  'Product Manager': 48,
#  'Defect Detection': 49,
#  'Performance Testing': 50,
#  'SQL (Structured Query Language)': 51,
#  'Usability Testing': 52,
#  'Regression Testing': 53,
#  'Source Code Management': 54,
#  'API (Application Programming Interface)': 55,
#  'Database Querying': 56,
#  'Agile Methodology': 57,
#  'Quality Assurance': 58,
#  'Iterative Development': 59,
#  'Data Cleaning': 60,
#  'Prototyping': 61,
#  'Product Launch': 62,
#  'Tableau': 63,
#  'Testing Changes': 64,
#  'UI/UX Design Software': 65,
#  'Product Planning': 66,
#  'Collaborative Development': 67,
#  'Data Analytics': 68}

# %%
df['skills_list'] = df['skills_list'].apply(lambda skills: [skill_mapping.get(skill) for skill in skills if skill in skill_mapping])
df.head()
# Out:
#    question_id  field_id                                           question  \
# 0            1         1  What is the purpose of a version control syste...
# 1            2         1   What does DRY stand for in software development?
# 2            3         1  Which programming language is known for its us...
# 3            4         1  What does the term "API" stand for in software...
# 4            5         1  What is the primary purpose of unit testing in...
#
#                                          description  \
# 0  Select the most accurate answer related to ver...
# 1   Choose the correct expansion of the acronym DRY.
# 2  Identify the programming language commonly ass...
# 3              Select one option you think is right.
# 4         Select the main objective of unit testing.
#
#                                              options  correct_option  \
# 0  ["To track changes in code", "To format text",...               0
# 1  ["Don't Repeat Yourself", "Design Reusable Yie...               0
# 2                  ["Java", "Python", "Ruby", "C++"]               0
# 3  ["Application Programming Interface", "Advance...               0
# 4  ["To test individual components or functions",...               0
#
#     skills_list
# 0  [19, 54, 67]
# 1   [24, 3, 41]
# 2   [31, 33, 4]
# 3    [55, 1, 8]
# 4   [36, 6, 20]

# %%
test_df = df.explode('skills_list')
# get only question_id and skills_list
test_df = test_df[['question_id', 'skills_list']]
test_df
# Out:
#     question_id skills_list
# 0             1          19
# 0             1          54
# 0             1          67
# 1             2          24
# 1             2           3
# ..          ...         ...
# 28           29          35
# 28           29          11
# 29           30          22
# 29           30          35
# 29           30          11
#
# [94 rows x 2 columns]

# %%
test_df = test_df.rename(columns={'skills_list': 'skill_id'})
test_df
# Out:
#     question_id skill_id
# 0             1       19
# 0             1       54
# 0             1       67
# 1             2       24
# 1             2        3
# ..          ...      ...
# 28           29       35
# 28           29       11
# 29           30       22
# 29           30       35
# 29           30       11
#
# [94 rows x 2 columns]

# %%
# add test_skill_id column
test_df['id'] = np.arange(len(test_df)) + 1
test_df
# Out:
# C:\Users\aky\AppData\Local\Temp\ipykernel_19008\3030737366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['id'] = np.arange(len(test_df)) + 1
#     test_skill_id  question_id skill_id  id
# 0               1            1       19   1
# 0               2            1       54   2
# 0               3            1       67   3
# 1               4            2       24   4
# 1               5            2        3   5
# ..            ...          ...      ...  ..
# 28             90           29       35  90
# 28             91           29       11  91
# 29             92           30       22  92
# 29             93           30       35  93
# 29             94           30       11  94
#
# [94 rows x 4 columns]

# %%
# reorder columns
test_df = test_df[['id', 'question_id', 'skill_id']]
test_df
# Out:
#     id  question_id skill_id
# 0    1            1       19
# 0    2            1       54
# 0    3            1       67
# 1    4            2       24
# 1    5            2        3
# ..  ..          ...      ...
# 28  90           29       35
# 28  91           29       11
# 29  92           30       22
# 29  93           30       35
# 29  94           30       11
#
# [94 rows x 3 columns]

# %%
# save to csv
test_df.to_csv('../../static/csv/test_skill.csv', index=False)
